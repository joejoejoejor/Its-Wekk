# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame

#df = pd.read_csv("./puenktlichkeit.csv")
df1 = pd.read_excel("./strassenverkehrsunfallorte.xlsx")
#df2 = pd.read_csv("./wetterdaten-klimamessnetz-kanton-stgallen-tageswerte.xlsx")


# Display the first few rows of the DataFrame
df1.head()
# Out:
#                         AccidentUID AccidentType  \
# 0  BB6028C692E40008E0430A8394270008          at2
# 1  BB6E7C0117BADFD0E053DDB9D80ACC29          at0
# 2  BBE57AA4F91C00EAE0430A83942700EA          at2
# 3  BC9EEFBDE8200038E0430A8394270038          at3
# 4  BCAD5DED2B7001F6E0430A83942701F6          at0
#
#                 AccidentType_de                 AccidentType_fr  \
# 0                 Auffahrunfall       accident par tamponnement
# 1  Schleuder- oder Selbstunfall   dérapage ou perte de maîtrise
# 2                 Auffahrunfall       accident par tamponnement
# 3                 Abbiegeunfall  accident en quittant une route
# 4  Schleuder- oder Selbstunfall   dérapage ou perte de maîtrise
#
#                                 AccidentType_it  \
# 0                     Incidente di tamponamento
# 1  Incidente di sbandamento o per colpa propria
# 2                     Incidente di tamponamento
# 3                      Incidente nello svoltare
# ...
