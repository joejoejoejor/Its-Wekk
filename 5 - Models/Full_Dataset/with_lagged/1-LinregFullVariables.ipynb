# %%
import pandas as pd
features = pd.read_csv('../../../4 - Data/04_WorkingDatasets/02 NormalCombLagged/WDFCombLagged.csv')
target = pd.read_csv('../../../4 - Data/04_WorkingDatasets/02 NormalCombLagged/TargetOutliersTreated.csv')

# %%
# Ensure the features and target dataframes have similar lengths
min_length = min(len(features), len(target))
features = features.iloc[:min_length]
target = target.iloc[:min_length]

# Print the lengths to verify
print(f"Length of features dataframe: {len(features)}")
print(f"Length of target dataframe: {len(target)}")
# Out:
# Length of features dataframe: 24549
# Length of target dataframe: 24549

# %%
from sklearn.model_selection import train_test_split

# Ensure the features and target dataframes are correctly assigned
if 'Datum' in features.columns:
	features = features.drop(columns=['Datum'])
target = target['PM10_Combined_Trend_Residual']


# Split the data into train, test, and validate sets
train_data, temp_data, train_target, temp_target = train_test_split(features, target, test_size=0.3, random_state=11)# letter K in Alphabet
test_data, validate_data, test_target, validate_target = train_test_split(temp_data, temp_target, test_size=0.3333, random_state=11)# letter K in Alphabet

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from tqdm import tqdm
from joblib import Parallel, delayed
import numpy as np

# Define a smaller parameter grid for GridSearchCV
param_grid = {
    'alpha': [0.0001, 0.001],
    'eta0': [0.01, 0.1],
    'learning_rate': ['constant', 'optimal'],
    'penalty': ['l2', 'l1', None]
}

# Initialize the SGDRegressor
sgd = SGDRegressor(max_iter=1000, tol=1e-3)

# Initialize GridSearchCV with fewer cross-validation folds
grid_search = GridSearchCV(sgd, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)

# Fit the model
grid_search.fit(train_data, train_target.values.ravel())

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Plot the progress bar
progress_bar = tqdm(total=100)
for i in range(100):
    progress_bar.update(1)
progress_bar.close()

# Print the best parameters and best score
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Evaluate the model on the test set
predictions = grid_search.predict(test_data)
predictions = np.maximum(predictions, 0)  # Ensure predictions are not lower than zero
mse = mean_squared_error(test_target, predictions)
print("Mean Squared Error on Test Set:", mse)

# Evaluate the model on the validation set
validate_predictions = grid_search.predict(validate_data)
validate_predictions = np.maximum(validate_predictions, 0)  # Ensure predictions are not lower than zero
validate_mse = mean_squared_error(validate_target, validate_predictions)
print("Mean Squared Error on Validation Set:", validate_mse)

# Expanding CV Fold Sizes
initial_train_size = int(0.5 * len(train_data))
test_size = int(0.1 * len(train_data))
num_folds = (len(train_data) - initial_train_size) // test_size

def train_and_evaluate_fold(fold):
    start_train_size = initial_train_size + fold * test_size
    end_train_size = start_train_size + test_size

    X_train_fold = train_data[:end_train_size]
    y_train_fold = train_target[:end_train_size]
    X_test_fold = train_data[end_train_size:end_train_size + test_size]
    y_test_fold = train_target[end_train_size:end_train_size + test_size]

    model = SGDRegressor(**best_params, max_iter=1000, tol=1e-3)
    model.fit(X_train_fold, y_train_fold)
    fold_predictions = model.predict(X_test_fold)
    fold_predictions = np.maximum(fold_predictions, 0)  # Ensure predictions are not lower than zero
    fold_mse = mean_squared_error(y_test_fold, fold_predictions)
    return fold, fold_mse

results = Parallel(n_jobs=-1)(delayed(train_and_evaluate_fold)(fold) for fold in range(num_folds))

for fold, fold_mse in results:
    print(f"Fold {fold + 1}/{num_folds}, MSE: {fold_mse}")
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=l1; total time=   0.4s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=l1; total time=   0.4s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=l1; total time=   0.4s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=None; total time=   0.2s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=None; total time=   0.4s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=constant, penalty=None; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=l2; total time=   3.5s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=l2; total time=   3.6s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=None; total time=   4.0s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=None; total time=   4.2s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=l2; total time=   4.6s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=l2; total time=   0.6s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=l2; total time=   0.5s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=l1; total time=   0.4s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=l1; total time=   0.5s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=None; total time=   0.2s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=None; total time=   0.2s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=None; total time=   0.5s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=constant, penalty=l1; total time=   1.0s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=l1; total time=   6.4s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=l1; total time=   7.1s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=l1; total time=   8.0s
# [CV] END alpha=0.0001, eta0=0.01, learning_rate=optimal, penalty=None; total time=   5.0s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=l2; total time=   6.0s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=l2; total time=   5.7s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=l2; total time=   6.7s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=l2; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=l1; total time=   0.4s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=l1; total time=   0.3s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=None; total time=   4.7s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=l1; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=None; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=None; total time=   0.2s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=constant, penalty=None; total time=   0.2s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=None; total time=   4.8s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   7.7s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=l2; total time=   0.8s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=l2; total time=   0.6s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=l2; total time=   0.9s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=None; total time=   1.5s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=l1; total time=   2.0s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   7.9s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=None; total time=   4.5s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=l2; total time=   0.4s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=None; total time=   2.0s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=l1; total time=   0.4s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=l1; total time=   2.6s
# [CV] END alpha=0.0001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   9.8s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=l2; total time=   0.7s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=l2; total time=   0.7s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=l1; total time=   2.8s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=l1; total time=   0.7s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=None; total time=   0.2s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=None; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=None; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=constant, penalty=l1; total time=   0.3s
# [CV] END alpha=0.001, eta0=0.01, learning_rate=optimal, penalty=None; total time=   1.5s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l2; total time=   0.7s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l2; total time=   0.8s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l2; total time=   0.7s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=None; total time=   0.6s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=None; total time=   0.7s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=None; total time=   1.0s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   1.1s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   1.2s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   1.3s
# 100%|██████████| 100/100 [00:00<00:00, 438734.73it/s]
# Best Parameters: {'alpha': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal', 'penalty': 'l1'}
# Best Score: -8.640887131933403e+20
# Mean Squared Error on Test Set: 1.8241378187434637e+19
# Mean Squared Error on Validation Set: 1.8414885151188666e+19
# Fold 1/5, MSE: 1.4890612663390741e+21
# Fold 2/5, MSE: 1.0924688518002517e+21
# Fold 3/5, MSE: 3.066765954491173e+20
# Fold 4/5, MSE: 2.0920654498205266e+19
# Fold 5/5, MSE: 292.63205753265504

# %%
# Define a more focused parameter grid for GridSearchCV based on the best parameters
refined_param_grid = {
    'alpha': [best_params['alpha'] * 0.5, best_params['alpha'], best_params['alpha'] * 5],
    'eta0': [best_params['eta0'] * 0.5, best_params['eta0'], best_params['eta0'] * 5],
    'learning_rate': [best_params['learning_rate']],
    'penalty': [best_params['penalty']]
}

# Initialize a new GridSearchCV with the refined parameter grid
refined_grid_search = GridSearchCV(sgd, refined_param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)

# Fit the model with the refined parameter grid
refined_grid_search.fit(train_data, train_target.values.ravel())

# Get the best parameters and best score from the refined search
refined_best_params = refined_grid_search.best_params_
refined_best_score = refined_grid_search.best_score_

# Print the refined best parameters and best score
print("Refined Best Parameters:", refined_best_params)
print("Refined Best Score:", refined_best_score)

# Evaluate the refined model on the test set
refined_predictions = refined_grid_search.predict(test_data)
refined_mse = mean_squared_error(test_target, refined_predictions)
print("Refined Mean Squared Error on Test Set:", refined_mse)

# Evaluate the refined model on the validation set
refined_validate_predictions = refined_grid_search.predict(validate_data)
refined_validate_mse = mean_squared_error(validate_target, refined_validate_predictions)
print("Refined Mean Squared Error on Validation Set:", refined_validate_mse)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END alpha=0.0005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   1.9s
# [CV] END alpha=0.0005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   1.9s
# [CV] END alpha=0.0005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.2s
# [CV] END alpha=0.0005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.1s
# [CV] END alpha=0.0005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.3s
# [CV] END alpha=0.0005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.3s
# [CV] END alpha=0.0005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.6s
# [CV] END alpha=0.0005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   2.3s
# [CV] END alpha=0.0005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   2.3s
# [CV] END alpha=0.0005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   2.3s
# [CV] END alpha=0.0005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.9s
# [CV] END alpha=0.0005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.9s
# [CV] END alpha=0.0005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   3.0s
# [CV] END alpha=0.0005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   2.5s
# [CV] END alpha=0.001, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.2s
# [CV] END alpha=0.001, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.2s
# [CV] END alpha=0.001, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.3s
# [CV] END alpha=0.001, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.4s
# [CV] END alpha=0.001, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   2.6s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.2s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   1.6s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   1.2s
# [CV] END alpha=0.001, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   1.3s
# [CV] END alpha=0.001, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   1.6s
# [CV] END alpha=0.001, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   1.4s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   2.0s
# [CV] END alpha=0.005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   0.9s
# [CV] END alpha=0.005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   0.9s
# [CV] END alpha=0.001, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   1.5s
# [CV] END alpha=0.001, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   4.3s
# [CV] END alpha=0.001, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   1.5s
# [CV] END alpha=0.005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   0.9s
# [CV] END alpha=0.0005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=  10.3s
# [CV] END alpha=0.005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=   0.9s
# [CV] END alpha=0.005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   0.5s
# [CV] END alpha=0.005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   0.7s
# [CV] END alpha=0.005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   0.7s
# [CV] END alpha=0.005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=   0.7s
# [CV] END alpha=0.005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   0.7s
# [CV] END alpha=0.005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   0.6s
# [CV] END alpha=0.005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   0.6s
# [CV] END alpha=0.005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=   0.8s
# /Users/johannessolibieda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END alpha=0.005, eta0=0.05, learning_rate=optimal, penalty=l1; total time=  25.3s
# /Users/johannessolibieda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/johannessolibieda/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END alpha=0.005, eta0=0.1, learning_rate=optimal, penalty=l1; total time=  24.8s
# [CV] END alpha=0.005, eta0=0.5, learning_rate=optimal, penalty=l1; total time=  24.3s
# Refined Best Parameters: {'alpha': 0.005, 'eta0': 0.05, 'learning_rate': 'optimal', 'penalty': 'l1'}
# Refined Best Score: -2.058913324936107e+20
# Refined Mean Squared Error on Test Set: 6.224018182941108e+19
# Refined Mean Squared Error on Validation Set: 5.513248817729457e+19
